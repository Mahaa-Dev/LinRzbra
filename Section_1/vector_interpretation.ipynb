# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## Algebric and Geometric interpretation

# %%
#2-dimensional vector
v2 = [3, -2]

# 3 - dimensional vector
v3 = [4, -3, 2]

#row to column (or vice versa):
v3t = np.transpose(v3)

#plot them
plt.plot([0,v2[0]],[0,v2[1]])
plt.axis('equal')
plt.plot([-4, 4],[0, 0],'k--')
plt.plot([0, 0],[-4, 4],'k--')
plt.grid()
plt.axis((-4, 4, -4, 4))
plt.show()

#plot the 3d vector
fig = plt.figure(figsize=plt.figaspect(1))
ax = fig.gca(projection='3d')
ax.plot([0, v3[0]],[0, v3[1]], [0, v3[2]],linewidth=3)

#make the plot look nicer
ax.plot([0, 0],[0, 0],[-4, 4], 'k--')
ax.plot([0, 0],[-4, 4],[0, 0], 'k--')
ax.plot([-4, 4],[0, 0],[0, 0], 'k--')
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp/ipykernel_17928/2050911466.py:21: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %% [markdown]
# ## Vcetor Addition & Substraction

# %%
# two vectors in R2
v1 = np.array([3, -1])
v2 = np.array([2, 4])

v3 = v1 + v2

#plot them
plt.plot([0, v1[0]],[0, v1[1]], 'b',label='v1')
plt.plot([0, v2[0]] + v1[0],[0,v2[1]]+v1[1],'r',label='v2')
plt.plot([0,v3[0]],[0,v3[1]],'k',label='v1+v2')

plt.legend()
plt.axis('square')
plt.axis((-6,6,-6,6))
plt.grid()
plt.show()

# %% [markdown]
# ## vector scalar multiplication

# %%
# vector and scalar
v1 = np.array([3, -1])
l=-.3
v1m = v1*l #scalar modulated

#plot them
plt.plot([0, v1[0]],[0, v1[1]],'b',label='v_1')
plt.plot([0, v1m[0]],[0, v1m[1]],'r:',label='\lambda v_1')

plt.axis('square')
axlim = max([abs(max(v1)),abs(max(v1m))])*1.5 #dynamic axis lim
plt.axis((-axlim,axlim,-axlim,axlim))
plt.grid()
plt.show()

# %% [markdown]
# ## Vector dot product

# %%
## many ways to compute the dot product
v1 = np.array([1, 2, 3, 4, 5, 6])
v2 = np.array([0, -4,2,-3, 6, 5])

# method 1
dp1 = sum(np.multiply(v1, v2))

# method 2
dp2 = np.dot (v1, v2)

# method 3
dp3 = np.matmul(v1, v2)

# method 4
dp4 = 0 #initialize

# Loop over elements
for i in range(0,len(v1)):
    #multiply corresponding element and sum
    dp4 = dp4 + v1[i]*v2[i]

print(dp1,dp2,dp3,dp4)
# Out:
# 46 46 46 46

# %% [markdown]
# ## Dot product properties

# %% [markdown]
# ### distributive a(b+c) = ab + ac, aT(b+c) = aTb + aTc

# %% [markdown]
# ### vector product is asscociative but dot product is not
# ### a(b . c) = (a. b)c
# ### aT(bTc) not equal (aTb)Tc

# %%
# distibutive property
#create random vectors
n=10
a = np.random.randn(n)
b= np.random.rand(n)
c = np.random.randn(n)

#the two results
res1 = np.dot(a, (b+c))
res2 = np.dot(a,b) + np.dot(a,c)

#compare them
print([res1,res2])
# Out:
# [-2.6363769103497985, -2.6363769103497994]

# %%
# Associative property
#create random vectors
n=5
a = np.random.randn(n)
b= np.random.rand(n)
c = np.random.randn(n)

#the two results
res1 = np.dot(a, np.dot(b,c))
res2 = np.dot(np.dot(a,b), c)

#compare them
print(res1)
print(res2)

### Special cases where associative property works!
# 1) one vector is the zeros vector
# 2) a==b==c
# Out:
# [-0.83887187 -0.20782591 -0.41172653 -0.32865507  0.40173535]
# [-0.63873997  0.00180945 -1.18210271  0.39211018 -0.14931023]

# %%
A = np.random.randn(4,6)
B = np.random.randn(4,6)
print(A)
print(B)

dps = np.zeros(6)
for i in range(6):
    dps[i] = np.dot(A[:,i],B[:,i])

print(' ')
print(dps)
# Out:
# [[ 0.95960392 -0.91394667  1.5900867   0.43722555  1.02564949  1.0180525 ]
#  [ 0.27545842 -1.43863378 -0.46451192  0.80017756  1.53320234  0.22829324]
#  [-0.00280307  0.49685621  1.33049397 -0.36448172 -0.16670013 -0.5379984 ]
#  [-0.04292746 -2.03370526 -1.34582617  0.54967547  1.07677621 -1.69179013]]
# [[-0.13404967 -0.22736305  0.15643786 -0.68406136  1.03362136  1.78382738]
#  [ 0.16166132  0.76893212  0.06293954  0.28121151 -0.26895084 -0.8315481 ]
#  [ 0.28415687 -0.37992857 -0.82179344  0.52139953 -1.60569257 -0.49051795]
#  [ 0.15869795 -0.49763396  0.14522175 -0.76851097  0.35066742  0.61064222]]
#
# [-0.09171263 -0.07514307 -1.06932086 -0.68654218  1.29303665  0.85701251]

# %%
# is the dot product commutative

#generate two 100-element vectors
a=np.random.randn(100)
b=np.random.randn(100)

# compute a'b and b'a test for equality
dp_ab = np.dot(a,b)
dp_ba = np.dot(b,a)
print(dp_ab, dp_ba, dp_ab-dp_ba)
print('')
# Out:
# 24.5020701414411 24.5020701414411 0.0

# %%
# a vector
v1 = np.array([1, 2, 3, 4, 5, 6])

vl1 = np.sqrt(sum(np.multiply(v1,v1)))
vl2 = np.linalg.norm(v1)
print(vl1,vl2)
# Out:
# 9.539392014169456 9.539392014169456

# %%
# two vectors
v1 = np.array([16, -2, 4])
v2 = np.array([0.5, 2, -1])

# compute the angle radians between two vectors
angl = np.arccos(np.dot(v1,v2) / (np.linalg.norm(v1)*np.linalg.norm(v2)))
print(angl)

#draw them
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot([0, v1[0]],[0, v1[1]],[0, v1[2]],'b')
ax.plot([0, v2[0]],[0, v2[1]],[0,v2[2]],'r')

plt.axis((-6, 6, -6, 6))
plt.title('Angle between vectors: %s rad.' %angl)
plt.show()
# Out:
# 1.5707963267948966
# C:\Users\Acer\AppData\Local\Temp/ipykernel_17928/3095819952.py:11: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
## create 3 vectors
s = np.random.randn(5)
k = np.random.randn(5)
y = np.random.randn(1) * s

## dot products
sTk = np.dot(s,k)
sTy = np.dot(s,y)

#demonstrate the (in) equalities
print(f'{np.abs(sTk):.4f}, {np.linalg.norm(s)*np.linalg.norm(k):.4f}')
print(f'{np.abs(sTy):.4f}, {np.linalg.norm(s)*np.linalg.norm(y):.4f}')
# Out:
# 2.3337, 4.1350
# 3.5373, 3.5373

# %%
#dot product
v1 = np.array([3, 4, 5, 6])
v2 = np.array([7, 1, 8, 9])

#generate scalar value
s1 = 2
s2 = 3

#
print("Original dot product is: "+str(np.dot(v1,v2)))
print("Scaled dot product is : "+str(np.dot(s1*v1,s2*v2)))
# Out:
# Original dot product is: 119
# Scaled dot product is : 714

# %%
## vector hadamard multiplication
w1 = np.array([2, 4, 6, 8])
w2 = np.array([3, 5, 7, 9])

w3 = np.multiply(w1, w2)#element-wise multiplication
print(w3)
# Out:
# [ 6 20 42 72]

# %%
#outer product
v3 = np.array([3, 4, 5])
v4 = np.array([6, 7, 8])

op1 = np.outer(v3, v4)

op2 = np.zeros((len(v3),len(v4)))

for i in range(0, len(v3)):
    for j in range(0, len(v4)):
        op2[i, j] = v3[i] * v4[j]
print(op1)
print(' ')
print(op2)
# Out:
# [[18 21 24]
#  [24 28 32]
#  [30 35 40]]
#
# [[18. 21. 24.]
#  [24. 28. 32.]
#  [30. 35. 40.]]

# %%
#vector cross produt
v5 = np.array([2, 3, 4])
v6 = np.array([1, 3, 5])
vc1 = np.cross(v5, v6)#vector cross product
vc2 = [[v5[1]*v6[2] - v5[2]*v6[1]],
       [v5[2]*v6[0] - v5[0]*v6[2]],
       [v5[0]*v6[1] - v5[1]*v6[0]]]

print(vc1, vc2)
fig = plt.figure()
ax = fig.gca(projection='3d')

#draw plane defined by span of v5 and v6
xx, yy = np.meshgrid(np.linspace(-10,10,10),np.linspace(-10,10,10))
z1 = (-vc1[0]*xx - vc1[1]*yy)/vc1[2]
ax.plot_surface(xx,yy,z1)

##plot the two vectors
ax.plot([0, v5[0]],[0, v5[1]], [0, v5[2]],'k')
ax.plot([0, v6[0]],[0, v6[1]], [0, v6[2]],'k')
ax.plot([0, vc1[0]],[0, vc1[1]], [0, vc1[2]],'k')

ax.view_init(azim=150,elev=45)
plt.show()
# Out:
# [ 3 -6  3] [[3], [-6], [3]]
# C:\Users\Acer\AppData\Local\Temp/ipykernel_17928/500254681.py:11: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
#complex number
z = 1.0 + 2.0j
real = z.real
imag = z.imag

plt.scatter(real, imag)
plt.axis('equal')
plt.show()

# %%
import cmath
import math
# Get magnitude and phase of the complex number
mag, phase = cmath.polar(z)

# Calculate x and y coordinates of the vector
x = mag * math.cos(phase)
y = mag * math.sin(phase)

# Plot the vector
plt.quiver(0, 0, x, y, angles='xy', scale_units='xy', scale=1, color='red')
plt.axis('equal')
plt.show()

# %%
# Create an array of complex numbers
z_array = [1 + 2j, 3 + 4j, -1 - 1j, 2 - 3j]

# Loop over the array and plot each complex number
for z in z_array:
    real = z.real
    imag = z.imag
    plt.scatter(real, imag)

plt.axis('equal')
plt.show()

# %%
# import cmath
# import math

# Create an array of complex numbers
z_array = [1 + 2j, 3 + 4j, -1 - 1j, 2 - 3j]

# Loop over the array and plot each complex number as a vector
for z in z_array:
    # Get magnitude and phase of the complex number
    mag, phase = cmath.polar(z)

    # Calculate x and y coordinates of the vector
    x = mag * math.cos(phase)
    y = mag * math.sin(phase)

    # Plot the vector
    plt.quiver(0, 0, x, y, angles='xy', scale_units='xy', scale=1, color='red')

plt.axis('equal')
plt.show()
