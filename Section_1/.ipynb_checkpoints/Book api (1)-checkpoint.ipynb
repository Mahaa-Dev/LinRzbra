# %%
import requests
import pandas as pd
import json
from pandas import json_normalize

# %%
response = requests.get('https://www.googleapis.com/books/v1/volumes?q=search-terms&key=AIzaSyDJV1BCnH9q1UZxf1iXqiwtD-UYS_sPSbM')

# %%
df = pd.DataFrame(response.json()['items'])
df
#items(volumeInfo/description,volumeInfo/title)
# Out:
#            kind            id         etag  \
# 0  books#volume  zYw3sYFtz9kC  Y543xrQDZx4
# 1  books#volume  SNAjMMp3H5UC  gHvZuaqVqmY
# 2  books#volume  DgbhAAAAMAAJ  Cv+znU69Ajk
# 3  books#volume  77RZAAAAYAAJ  iayvDp0YVeY
# 4  books#volume  T7nuAAAAMAAJ  d6DfuBBp+YA
# 5  books#volume  tsnKDwAAQBAJ  j1OpcQSZS58
# 6  books#volume  osAaZHcEbtkC  AFlFvf9K94I
# 7  books#volume  OMOwmLgbMfYC  WNdFstaBk8Q
# 8  books#volume  gqDf__ULmR8C  diQmCXmZd6o
# 9  books#volume  -CL-DFQYoc8C  /hLc2TBOjgQ
#
#                                             selfLink  \
# 0  https://www.googleapis.com/books/v1/volumes/zY...
# 1  https://www.googleapis.com/books/v1/volumes/SN...
# 2  https://www.googleapis.com/books/v1/volumes/Dg...
# 3  https://www.googleapis.com/books/v1/volumes/77...
# 4  https://www.googleapis.com/books/v1/volumes/T7...
# 5  https://www.googleapis.com/books/v1/volumes/ts...
# 6  https://www.googleapis.com/books/v1/volumes/os...
# 7  https://www.googleapis.com/books/v1/volumes/OM...
# ...

# %%
a = df['volumeInfo'][0]
a
# Out:
# {'title': 'The Contemporary Thesaurus of Search Terms and Synonyms',
#  'subtitle': 'A Guide for Natural Language Computer Searching',
#  'authors': ['Sara D. Knapp'],
#  'publisher': 'Greenwood Publishing Group',
#  'publishedDate': '2000',
# ...

# %%
import ast




# [0])[['title', 'subtitle', 'description', 'averageRating','imageLinks',ratingsCount','maturityRating','previewLink']]

# %%
def convert(obj):
    l=[]
    for i in ast.literal_eval(obj):
        l.append(i['a'])
    return l

# %%
df['volumeInfo'].apply(convert)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23420/1336767760.py in <module>
# ----> 1 df['volumeInfo'].apply(convert)
#
# c:\users\acer\appdata\local\programs\python\python39\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# c:\users\acer\appdata\local\programs\python\python39\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# c:\users\acer\appdata\local\programs\python\python39\lib\site-packages\pandas\core\apply.py in apply_standard(self)
# ...

# %%
b = pd.json_normalize(df['volumeInfo'])
b
# Out:
#                                                title  \
# 0  The Contemporary Thesaurus of Search Terms and...
# 1                               Keyword Intelligence
# 2                                     Search INFORM.
# 3                      Pennsylvania Law Encyclopedia
# 4           Hands-on Information Literacy Activities
# 5                                From Hope to Horror
# 6                         Mastering Search Analytics
# 7               Out's Gay & Lesbian Guide to the Web
# 8                   Flexible Query Answering Systems
# 9                           Searching Skills Toolkit
#
#                                             subtitle  \
# 0    A Guide for Natural Language Computer Searching
# 1    Keyword Research for Search, Social, and Beyond
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5    Diplomacy and the Making of the Rwanda Genocide
# ...

# %%
# maile ta ['title', 'subtitle', 'description', 'averageRating','imageLinks',ratingsCount','maturityRating','previewLink',
'infoLink''] yo sabai lai dataframe ma convert garana khosjko (yo sabai lai coloumn form ma convert garna khojeko)

# %%
df1 = pd.DataFrame.from_dict(b)

# %%
df1.shape
# Out:
# (10, 25)

# %%
colname = list(df1.columns)

# %%
colname
# Out:
# ['title',
#  'subtitle',
#  'authors',
#  'publisher',
#  'publishedDate',
#  'description',
#  'industryIdentifiers',
#  'pageCount',
#  'printType',
#  'categories',
#  'averageRating',
#  'ratingsCount',
#  'maturityRating',
#  'allowAnonLogging',
#  'contentVersion',
#  'language',
#  'previewLink',
#  'infoLink',
#  'canonicalVolumeLink',
#  'readingModes.text',
#  'readingModes.image',
#  'panelizationSummary.containsEpubBubbles',
#  'panelizationSummary.containsImageBubbles',
#  'imageLinks.smallThumbnail',
#  'imageLinks.thumbnail']

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 25 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   title                                     10 non-null     object
#  1   subtitle                                  6 non-null      object
#  2   authors                                   8 non-null      object
#  3   publisher                                 8 non-null      object
#  4   publishedDate                             10 non-null     object
#  5   description                               8 non-null      object
#  6   industryIdentifiers                       10 non-null     object
#  7   pageCount                                 9 non-null      float64
#  8   printType                                 10 non-null     object
#  9   categories                                10 non-null     object
# ...

# %%
df1.dtypes
# Out:
# title                                        object
# subtitle                                     object
# authors                                      object
# publisher                                    object
# publishedDate                                object
# description                                  object
# industryIdentifiers                          object
# pageCount                                   float64
# printType                                    object
# categories                                   object
# averageRating                               float64
# ratingsCount                                float64
# maturityRating                               object
# allowAnonLogging                               bool
# contentVersion                               object
# language                                     object
# previewLink                                  object
# infoLink                                     object
# ...
